# %% [markdown]
# <a href="https://colab.research.google.com/github/Vangolds/DPDM/blob/master/Pandas_and_Data_Preprocessing_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![เดซี่.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## First, we have to say which packages we are going to use by <font color=green>import</font> them.

# %%
import pandas

# %% [markdown]
# ## Connect with Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Create _path_ variables to store where is the data files

# %%
import os
import pandas as pd
base_path = '/content/drive/My Drive/DWDM_material'

# %% [markdown]
# ## Then use _pandas_ to load the data into the environment

# %%
search_click = os.path.join(base_path,'search_click.csv')

# %%
w_restaurant = os.path.join(base_path,'w_restaurant.csv')

# %%
search_click1 = pd.read_csv(search_click)

# %%
search_click1.head()
# Out:
#   click_timestamp                             search_id  ...  time_diff_nanos   ads
# 0         11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1  ...     2.222400e+15  True
# 1         30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e  ...     4.608380e+14  True
# 2         32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224  ...     2.581490e+15  True
# 3         00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b  ...     1.404580e+15  True
# 4         23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639  ...     9.333590e+14  True
#
# [5 rows x 6 columns]

# %%
w_restaurant1 = pd.read_csv(w_restaurant)

# %%
w_restaurant1.head()
# Out:
#    id              name  domain_id  ...  hotel_restaurant pet_friendly delivery
# 0   2  นครินทร์ทันตกรรม          2  ...               NaN          NaN      NaN
# 1   4      Corner House          1  ...               NaN          NaN      NaN
# 2   5    วัดโลกยสุธาราม          4  ...               NaN          NaN      NaN
# 3   6    นันท์คาราโอเกะ          1  ...               NaN          NaN      NaN
# 4   7       Buono Caffe          1  ...               NaN          NaN      NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# ## To check if the dimension of loaded data is correct as described in the description

# %%
search_click1.shape
# Out:
# (1048575, 6)

# %%
w_restaurant1.shape #(จน. แถว, จน. หลัก)
# Out:
# (246847, 32)

# %%
w_restaurant1.shape[0]
# Out:
# 246847

# %% [markdown]
# ## It seem everything is ok, let's have fun with data

# %% [markdown]
# ## 0. Point to data in the table

# %% [markdown]
# ### normal indexing

# %%
search_click1['search_id'] #เรียกใช้คอลัมน์นั้น
# Out:
# 0          5c004472-5ecc-4159-9698-9f329b8e26e1
# 1          5f34eca0-c04e-4c10-b600-54aa447dbd8e
# 2          8dc6d1f0-11f1-4239-9dd2-5c1674c81224
# 3          1a5810e9-3d1f-44b9-9a2e-26ede21c524b
# 4          6bc75e0d-fc65-471e-9926-ff6be6708639
#                            ...
# 1048570    99aab616-6fc5-4fbf-994b-4aebee7bb360
# 1048571    d70a2c5d-ee94-4e4c-9f7c-c5faac6db12a
# 1048572    4c1de7fe-300e-41aa-9d01-914344fc3753
# 1048573    2ec0ddec-e450-4b98-9779-42b77aa7eda5
# 1048574    5741d9cf-b9f1-441d-aa83-d2b0179bf874
# Name: search_id, Length: 1048575, dtype: object

# %%
 search_click1['search_id'][0] #เรียกใช้คอลัมน์นั้นตัวที่ 0
# Out:
# '5c004472-5ecc-4159-9698-9f329b8e26e1'

# %%
w_restaurant1[['name', 'city_name', 'weighted_average_rating']] #index[[#list ของคอลัมน์]]
# Out:
#                                         name  ... weighted_average_rating
# 0                           นครินทร์ทันตกรรม  ...                5.000000
# 1                               Corner House  ...                2.000000
# 2                             วัดโลกยสุธาราม  ...                4.000000
# 3                             นันท์คาราโอเกะ  ...                0.000000
# 4                                Buono Caffe  ...                3.738462
# ...                                      ...  ...                     ...
# 246842                            Sushi Tama  ...                3.663522
# 246843                     สะบายดี คาราโอเกะ  ...                0.000000
# 246844                      สเต็กแม่&กาแฟลูก  ...                4.000000
# 246845                              Mom Made  ...                5.000000
# 246846  ก๋วยเตี๋ยวหมูน้ำตก ก๋วยเตี๋ยวเรือทอง  ...                3.000000
#
# [246847 rows x 3 columns]

# %% [markdown]
# ### .iloc

# %%
search_click1.iloc[0,1] #มองเป็นเมทริกซ์ เรียก index matrix ค่าแถวที่ หลักที่เท่าไหร่
# Out:
# '5c004472-5ecc-4159-9698-9f329b8e26e1'

# %%
search_click1.iloc[:10,:2] #slicing เลือกบางส่วนได้ แถวแรกถึงแถวที่ 10 หลักแรกถึงหลักที่ 2
# Out:
#   click_timestamp                             search_id
# 0         11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1
# 1         30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e
# 2         32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224
# 3         00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b
# 4         23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639
# 5         48:16.7  92ea02ba-2c89-4efd-973c-e23526c531de
# 6         39:18.4  79d61918-fb3e-4181-99b6-7a7abddfcdb1
# 7         33:39.0  7f8b2b57-dea1-4fe1-84c8-5a7d63750e47
# 8         07:48.3  3d9217bb-3eae-42b5-8cf3-a756efae2cfa
# 9         41:25.4  a2cb0d41-6e1f-4169-9140-cb671fbb41dc

# %% [markdown]
# # 1 Missing Value

# %%
search_click1.isnull() #isnull check ว่าช่องนี้เป็น null รึเปล่า #null na none คือ  missing value
# Out:
#          click_timestamp  search_id  ...  time_diff_nanos    ads
# 0                  False      False  ...            False  False
# 1                  False      False  ...            False  False
# 2                  False      False  ...            False  False
# 3                  False      False  ...            False  False
# 4                  False      False  ...            False  False
# ...                  ...        ...  ...              ...    ...
# 1048570            False      False  ...            False  False
# 1048571            False      False  ...            False  False
# 1048572            False      False  ...            False  False
# 1048573            False      False  ...            False  False
# 1048574            False      False  ...            False  False
#
# [1048575 rows x 6 columns]

# %%
search_click1.isnull().any() #.any สรุปรวมควาามจริงทั้งหมดในด้านหลัก False คือไม่มี
# Out:
# click_timestamp     False
# search_id            True
# business_id          True
# display_position    False
# time_diff_nanos     False
# ads                 False
# dtype: bool

# %%
search_click1.isnull().any().any() #ดู missing value ทั้งตาราง
# Out:
# True

# %% [markdown]
# #Handling missing values 1

# %%
search_click1_nm = search_click1.dropna() #หายไปกี่ตัว

# %%
search_click1_nm.isnull().any().any()
# Out:
# False

# %%
print(search_click1.shape)
print(search_click1_nm.shape)
# Out:
# (1048575, 6)
# (1048206, 6)

# %%
search_click1.shape[0]-search_click1_nm.shape[0] #นับ จน
# Out:
# 369

# %% [markdown]
# #Exercise 1 ตรวจสอบว่า การลบข้อมูล missing ออกจาก ตร w จะทำให้ข้อมูลลดลดงกี่ %

# %%
w_restaurant1.isnull()
# Out:
#            id   name  domain_id  ...  hotel_restaurant  pet_friendly  delivery
# 0       False  False      False  ...              True          True      True
# 1       False  False      False  ...              True          True      True
# 2       False  False      False  ...              True          True      True
# 3       False  False      False  ...              True          True      True
# 4       False  False      False  ...              True          True      True
# ...       ...    ...        ...  ...               ...           ...       ...
# 246842  False  False      False  ...              True          True      True
# 246843  False  False      False  ...              True          True      True
# 246844  False  False      False  ...              True          True      True
# 246845  False  False      False  ...              True          True      True
# 246846  False  False      False  ...              True          True      True
#
# ...

# %%
w_restaurant1_nm = w_restaurant1.dropna()
w_restaurant1_nm.isnull().any().any()
# Out:
# False

# %%
print(w_restaurant1.shape)
print(w_restaurant1_nm.shape)
# Out:
# (246847, 32)
# (4, 32)

# %%
w_restaurant1.shape[0]-w_restaurant1_nm.shape[0]
# Out:
# 246843

# %%
((w_restaurant1.shape[0]-w_restaurant1_nm.shape[0])/w_restaurant1.shape[0])*100
# Out:
# 99.99837956304918

# %% [markdown]
# #Method 1.5

# %%
w_restaurant1.isnull().any()
# Out:
# id                         False
# name                       False
# domain_id                  False
# closed                     False
# city_name                  False
# zipcode                     True
# geohash                    False
# new_open                   False
# weighted_average_rating    False
# number_of_chains            True
# number_of_bookmarks         True
# number_of_reviews          False
# number_of_product_tags     False
# total_number_of_views      False
# number_of_checkins         False
# number_of_menu_groups      False
# number_of_menu_photos      False
# category_name              False
# price_range                 True
# avg_price                   True
# parking                     True
# credit_card_accepted        True
# good_for_groups             True
# good_for_kids               True
# bookable                    True
# best_of_wongnai             True
# wifi                        True
# number_of_seats             True
# ...

# %%
w_rest_dropped_avgprice = w_restaurant1.dropna(subset=['id','name','avg_price'])

# %%
w_rest_dropped_avgprice.head()
# Out:
#       id                         name  ...  pet_friendly  delivery
# 11    27              แพอาหารธาราบุรี  ...           NaN       NaN
# 67   123                  เล็กกุ้งเผา  ...           NaN       NaN
# 91   175                 ใต้ต้นมะม่วง  ...           NaN       NaN
# 129  262  Oniku Shabushabu & Yakiniku  ...           NaN       1.0
# 134  271                     Cafe Cha  ...           NaN       NaN
#
# [5 rows x 32 columns]

# %%
w_restaurant1.dropna(subset=['id','name','avg_price'])['avg_price'].mean()
# Out:
# 327.44728783902013

# %%
w_restaurant1['avg_price'].mean()
# Out:
# 327.44728783902013

# %% [markdown]
# #Method 2 (replace with reasonable value)
# we are replacing missing value in the number of chains with 0

# %%
w_restaurant1[['number_of_chains']] = w_restaurant1[['number_of_chains']].fillna(0)  #คอลัมน์นี้ ถูก fill ตัวที่ missing ด้วย 0 ทำไม 0 จึงเหมาะสม ร้านส่วนใหญ่ไม่ค่อยมีสาขา

# %%
w_restaurant1.isnull().any()
# Out:
# id                         False
# name                       False
# domain_id                  False
# closed                     False
# city_name                  False
# zipcode                     True
# geohash                    False
# new_open                   False
# weighted_average_rating    False
# number_of_chains           False
# number_of_bookmarks         True
# number_of_reviews          False
# number_of_product_tags     False
# total_number_of_views      False
# number_of_checkins         False
# number_of_menu_groups      False
# number_of_menu_photos      False
# category_name              False
# price_range                 True
# avg_price                   True
# parking                     True
# credit_card_accepted        True
# good_for_groups             True
# good_for_kids               True
# bookable                    True
# best_of_wongnai             True
# wifi                        True
# number_of_seats             True
# ...

# %% [markdown]
# #Method2.1 (replace withunknow value)
# ใส่ค่าไม่น่าเป็นจริงเช่น -99

# %% [markdown]
# #Method2.2 (replace with mean value)

# %% [markdown]
# #Method3
# แทนข้อมูลที่สูญหายด้วย ค่าเฉลี่ยข้อมูลที่อยู่ในคลาสเดียวกัน

# %%
new_table = w_restaurant1[['name','city_name','avg_price']]
new_table
# Out:
#                                         name  ... avg_price
# 0                           นครินทร์ทันตกรรม  ...       NaN
# 1                               Corner House  ...       NaN
# 2                             วัดโลกยสุธาราม  ...       NaN
# 3                             นันท์คาราโอเกะ  ...       NaN
# 4                                Buono Caffe  ...       NaN
# ...                                      ...  ...       ...
# 246842                            Sushi Tama  ...       NaN
# 246843                     สะบายดี คาราโอเกะ  ...       NaN
# 246844                      สเต็กแม่&กาแฟลูก  ...       NaN
# 246845                              Mom Made  ...       NaN
# 246846  ก๋วยเตี๋ยวหมูน้ำตก ก๋วยเตี๋ยวเรือทอง  ...       NaN
#
# [246847 rows x 3 columns]

# %% [markdown]
# ### [PD] select data

# %%
selected_list = new_table['city_name']=='Bangkok Metropolitan Region'
selected_list
# Out:
# 0         False
# 1          True
# 2         False
# 3          True
# 4          True
#           ...
# 246842     True
# 246843     True
# 246844     True
# 246845    False
# 246846    False
# Name: city_name, Length: 246847, dtype: bool

# %%
new_table[selected_list].head() #ดูแค่หัวตาราง
# Out:
#               name                    city_name  avg_price
# 1     Corner House  Bangkok Metropolitan Region        NaN
# 3   นันท์คาราโอเกะ  Bangkok Metropolitan Region        NaN
# 4      Buono Caffe  Bangkok Metropolitan Region        NaN
# 7         Sazanami  Bangkok Metropolitan Region        NaN
# 10  Rotee Me Chabu  Bangkok Metropolitan Region        NaN

# %%
selected_list = new_table['city_name']== 'Bangkok Metropolitan Region' #ไม่ใช่อันนี้จะเป็น false
selected_list
# Out:
# 0         False
# 1          True
# 2         False
# 3          True
# 4          True
#           ...
# 246842     True
# 246843     True
# 246844     True
# 246845    False
# 246846    False
# Name: city_name, Length: 246847, dtype: bool

# %%
new_table[selected_list].head()
# Out:
#               name                    city_name  avg_price
# 1     Corner House  Bangkok Metropolitan Region        NaN
# 3   นันท์คาราโอเกะ  Bangkok Metropolitan Region        NaN
# 4      Buono Caffe  Bangkok Metropolitan Region        NaN
# 7         Sazanami  Bangkok Metropolitan Region        NaN
# 10  Rotee Me Chabu  Bangkok Metropolitan Region        NaN

# %%
new_table[new_table['city_name']=='Bangkok Metropolitan Region'].head()
# Out:
#               name                    city_name  avg_price
# 1     Corner House  Bangkok Metropolitan Region        NaN
# 3   นันท์คาราโอเกะ  Bangkok Metropolitan Region        NaN
# 4      Buono Caffe  Bangkok Metropolitan Region        NaN
# 7         Sazanami  Bangkok Metropolitan Region        NaN
# 10  Rotee Me Chabu  Bangkok Metropolitan Region        NaN

# %% [markdown]
# ## หาราคาเฉลี่ยของร้านในจังหวัดกรุงเทพ

# %%
new_table[new_table['city_name']=='Bangkok Metropolitan Region'].dropna()['avg_price'].mean()
# Out:
# 392.5854715094968

# %% [markdown]
# 1. เลือกเฉพาะ กทม

# %%
bkk_table = new_table[new_table['city_name']=='Bangkok Metropolitan Region']
bkk_table.head()
# Out:
#               name                    city_name  avg_price
# 1     Corner House  Bangkok Metropolitan Region        NaN
# 3   นันท์คาราโอเกะ  Bangkok Metropolitan Region        NaN
# 4      Buono Caffe  Bangkok Metropolitan Region        NaN
# 7         Sazanami  Bangkok Metropolitan Region        NaN
# 10  Rotee Me Chabu  Bangkok Metropolitan Region        NaN

# %% [markdown]
# 2. ลบ missing

# %%
bkk_table_dp = bkk_table.dropna()
bkk_table_dp.head()
# Out:
#                             name                    city_name  avg_price
# 67                   เล็กกุ้งเผา  Bangkok Metropolitan Region      375.0
# 134                     Cafe Cha  Bangkok Metropolitan Region      175.0
# 247           Masterpiece clinic  Bangkok Metropolitan Region     1500.0
# 319  Chaba Nails & Eyelashes Pro  Bangkok Metropolitan Region      375.0
# 382                Panlee Bakery  Bangkok Metropolitan Region      175.0

# %% [markdown]
# 3. เลือกเฉพาะ column 'avg_price'

# %%
bkk_table_dp_avg_price = bkk_table_dp['avg_price']
bkk_table_dp_avg_price
# Out:
# 67         375.0
# 134        175.0
# 247       1500.0
# 319        375.0
# 382        175.0
#            ...
# 246458      50.0
# 246472    1500.0
# 246508     375.0
# 246666     375.0
# 246721     375.0
# Name: avg_price, Length: 3001, dtype: float64

# %% [markdown]
# 4. หาค่าเฉลี่ย

# %%
bkk_table_dp_avg_price.mean()
# Out:
# 392.5854715094968

# %% [markdown]
# ## แก้ missing method 3 เติมค่าที่เหมาะสมตามกลุ่มของมัน

# %%
bkk_table[['avg_price']] = bkk_table[['avg_price']].fillna(bkk_table_dp_avg_price.mean())
bkk_table.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#               name                    city_name   avg_price
# 1     Corner House  Bangkok Metropolitan Region  392.585472
# 3   นันท์คาราโอเกะ  Bangkok Metropolitan Region  392.585472
# 4      Buono Caffe  Bangkok Metropolitan Region  392.585472
# 7         Sazanami  Bangkok Metropolitan Region  392.585472
# 10  Rotee Me Chabu  Bangkok Metropolitan Region  392.585472

# %%
#bkk_table[['avg_price']].fillna(bkk_table_dp_avg_price.mean(),inplace=True)
#bkk_table.head()

# %% [markdown]
# #HW9 หาราคาเฉลี่ยของร้านค้าใน ภูเก็ต และเติมแทนค่า missing ของจังหวัดภูเก็ต

# %%
phuket_table = new_table[new_table['city_name'] == 'Phuket']
phuket_table.head()
# Out:
#                      name city_name  avg_price
# 53   เดอะฟอร์เต้ไอซ์แลนด์    Phuket        NaN
# 74    ร้านอาหารในยางปาร์ค    Phuket        NaN
# 91           ใต้ต้นมะม่วง    Phuket       50.0
# 96      อาหารเกาหลีชินจอง    Phuket        NaN
# 190            ไชน่าอินน์    Phuket        NaN

# %%
phuket_table_dp = phuket_table.dropna()
phuket_table_dp_avg_price = phuket_table_dp['avg_price']
phuket_table_dp_avg_price_mean = phuket_table_dp_avg_price.mean()

# %%
phuket_table_dp_avg_price.mean()
# Out:
# 181.4814814814815

# %%
phuket_table[['avg_price']] = phuket_table[['avg_price']].fillna(phuket_table_dp_avg_price.mean())
phuket_table.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                      name city_name   avg_price
# 53   เดอะฟอร์เต้ไอซ์แลนด์    Phuket  181.481481
# 74    ร้านอาหารในยางปาร์ค    Phuket  181.481481
# 91           ใต้ต้นมะม่วง    Phuket   50.000000
# 96      อาหารเกาหลีชินจอง    Phuket  181.481481
# 190            ไชน่าอินน์    Phuket  181.481481

# %% [markdown]
# ## [PD] ต่อตารางในแนวแกน Y (เพิ่มจำนวน data) pd.concat

# %%
cm_table = new_table[new_table['city_name']=='Chiang Mai']
cm_table[['avg_price']] = cm_table[['avg_price']].fillna(new_table[new_table['city_name']=='Chiang Mai'].dropna()['avg_price'].mean())
cm_table.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                             name   city_name   avg_price
# 36                   Wrap Master  Chiang Mai  188.415948
# 40                         Sozen  Chiang Mai  188.415948
# 52           ไวท์ดราก้อน หมูกะทะ  Chiang Mai  188.415948
# 60  เต-ชา ก๋วยเตี๋ยวไข่ไดโนเสาร์  Chiang Mai  188.415948
# 79            ก๋วยเตี๋ยวเรือสะใจ  Chiang Mai  188.415948

# %%
ch_table = new_table[new_table['city_name']=='Chon Buri']
ch_table[['avg_price']] = ch_table[['avg_price']].fillna(new_table[new_table['city_name']=='Chon Buri'].dropna()['avg_price'].mean())
ch_table.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                            name  city_name   avg_price
# 5                   บ้านมุมสบาย  Chon Buri  283.547619
# 15  The Rabbit หมูกระทะนานาชาติ  Chon Buri  283.547619
# 42       ก๋วยเตี๋ยวเป็ด ณ.พัทยา  Chon Buri  283.547619
# 45  ซันเซ็ทพาร์ครีสอร์ตแอนด์สปา  Chon Buri  283.547619
# 68          Oldies Bar & Bistro  Chon Buri  283.547619

# %%
import pandas

# %%
pandas.concat([bkk_table,phuket_table,ch_table])  #list ของตารางที่จะเอามาใส่ รวมตาราง 3 ตาราง
# Out:
#                             name                    city_name   avg_price
# 1                   Corner House  Bangkok Metropolitan Region  392.585472
# 3                 นันท์คาราโอเกะ  Bangkok Metropolitan Region  392.585472
# 4                    Buono Caffe  Bangkok Metropolitan Region  392.585472
# 7                       Sazanami  Bangkok Metropolitan Region  392.585472
# 10                Rotee Me Chabu  Bangkok Metropolitan Region  392.585472
# ...                          ...                          ...         ...
# 246754        บะหมี่หยก เป็ดย่าง                    Chon Buri  283.547619
# 246770              Café Terrace                    Chon Buri  283.547619
# 246782             CoCoICHIBANYA                    Chon Buri  283.547619
# 246804                Reva Beach                    Chon Buri  283.547619
# 246824  โรงแรมทาวน์อินทาวน์พัทยา                    Chon Buri  283.547619
#
# [119755 rows x 3 columns]

# %%
pd.concat([bkk_table,phuket_table,ch_table]).isnull().any()
# Out:
# name         False
# city_name    False
# avg_price    False
# dtype: bool

# %% [markdown]
# #Looping (concat)

# %% [markdown]
# ### 1. ดึงจังหวัดทั้งหมดในตารางออกมา มี 479 ตาราง

# %%
new_table['city_name']
# Out:
# 0                     Samut Songkhram
# 1         Bangkok Metropolitan Region
# 2            Phra Nakhon Si Ayutthaya
# 3         Bangkok Metropolitan Region
# 4         Bangkok Metropolitan Region
#                      ...
# 246842    Bangkok Metropolitan Region
# 246843    Bangkok Metropolitan Region
# 246844    Bangkok Metropolitan Region
# 246845            Nakhon Si Thammarat
# 246846                    Suphan Buri
# Name: city_name, Length: 246847, dtype: object

# %%
all_cities = set(new_table['city_name'])
print(len(all_cities))
#all_cities
# Out:
# 479

# %% [markdown]
# ###2. คำนวณค่า mean ของ column city name เพื่อเก็บไว้เติมใส่ เมืองที่เป็น missing ทุกร้าน

# %%
all_mean = new_table.dropna(subset=['avg_price'])['avg_price'].mean()
all_mean
# Out:
# 327.44728783902013

# %% [markdown]
# ### 3.สร้าง list ของตารางของทุก ๆ จังหวัด

# %%
all_cities_list = []
for each_city in sorted(list(all_cities)):  #วนลูปสร้างตารางทุกจังหวัด เอาค่าเฉลี่ยมเติม missing
  temp_table = new_table[new_table['city_name']== each_city]
  temp_table[['avg_price']] = temp_table[['avg_price']].fillna(new_table[new_table['city_name']== each_city ].dropna()['avg_price'].mean())
  all_cities_list.append(temp_table)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
pd.concat(all_cities_list)
# Out:
#                                 name  city_name  avg_price
# 56391   Smoking Doll Nation Galleria  Abu Dhabi        NaN
# 67914        PRET TO GO (Terminal 1)  Abu Dhabi        NaN
# 123536                     Keway Mai  Abu Dhabi        NaN
# 142972                    La Brioche  Abu Dhabi        NaN
# 223144               White Dot Table  Abu Dhabi        NaN
# ...                              ...        ...        ...
# 246412                   ครัวข้าวสวย    เขาใหญ่        NaN
# 246418             ร้านอาหารดาวเดือน    เขาใหญ่        NaN
# 246780                        กาแฟสด    เขาใหญ่        NaN
# 246791         ยู้ ลูกชิ้นปลาเยาวราช    เขาใหญ่        NaN
# 246832                     โชคดีกาแฟ    เขาใหญ่        NaN
#
# [246847 rows x 3 columns]

# %%
pd.concat(all_cities_list).dropna()
# Out:
#                                           name  ...   avg_price
# 1                                 Corner House  ...  392.585472
# 3                               นันท์คาราโอเกะ  ...  392.585472
# 4                                  Buono Caffe  ...  392.585472
# 7                                     Sazanami  ...  392.585472
# 10                              Rotee Me Chabu  ...  392.585472
# ...                                        ...  ...         ...
# 246245                        ภักดี โจ๊กหมูสับ  ...  375.000000
# 246492                         การ์เด้นรีสอร์ท  ...  375.000000
# 246630                          บอดิเวอร์กคาเฟ  ...  375.000000
# 246685                               คอฟฟี่ฮัท  ...  375.000000
# 246717  The Terrace Seafood & Restaurant สวนปู  ...  375.000000
#
# [163100 rows x 3 columns]

# %%
pd.concat(all_cities_list).fillna(all_mean) #เติม mean ทุกค่าที่เป็น Na ด้วย all_mean
# Out:
#                                 name  city_name   avg_price
# 56391   Smoking Doll Nation Galleria  Abu Dhabi  327.447288
# 67914        PRET TO GO (Terminal 1)  Abu Dhabi  327.447288
# 123536                     Keway Mai  Abu Dhabi  327.447288
# 142972                    La Brioche  Abu Dhabi  327.447288
# 223144               White Dot Table  Abu Dhabi  327.447288
# ...                              ...        ...         ...
# 246412                   ครัวข้าวสวย    เขาใหญ่  327.447288
# 246418             ร้านอาหารดาวเดือน    เขาใหญ่  327.447288
# 246780                        กาแฟสด    เขาใหญ่  327.447288
# 246791         ยู้ ลูกชิ้นปลาเยาวราช    เขาใหญ่  327.447288
# 246832                     โชคดีกาแฟ    เขาใหญ่  327.447288
#
# [246847 rows x 3 columns]

# %%
no_misssing = pd.concat(all_cities_list).fillna(all_mean)
no_misssing.head()
# Out:
#                                 name  city_name   avg_price
# 56391   Smoking Doll Nation Galleria  Abu Dhabi  327.447288
# 67914        PRET TO GO (Terminal 1)  Abu Dhabi  327.447288
# 123536                     Keway Mai  Abu Dhabi  327.447288
# 142972                    La Brioche  Abu Dhabi  327.447288
# 223144               White Dot Table  Abu Dhabi  327.447288

# %%
london_index_list = no_misssing['city_name'] == 'Greater London'  #อยากทราบของ london
no_misssing[london_index_list]
# Out:
#                                 name       city_name   avg_price
# 3580                     Greene King  Greater London  327.447288
# 5402                          Miyama  Greater London  327.447288
# 6375                          Misato  Greater London  327.447288
# 7644                 Duck And Waffle  Greater London  327.447288
# 8343      L'Atelier De Joel Robuchon  Greater London  327.447288
# ...                              ...             ...         ...
# 238648                           CnR  Greater London  327.447288
# 241688                       nando's  Greater London  327.447288
# 243077                      Cakehole  Greater London  327.447288
# 243749                  The Refinery  Greater London  327.447288
# 246443  Park Grand London Kensington  Greater London  327.447288
#
# [166 rows x 3 columns]

# %%
london_index_list = no_misssing['avg_price']<15  #มีร้านที่ราคาน้อยกว่า 15 มั้ย
no_misssing[london_index_list]
# Out:
#                                      name  ... avg_price
# 18161                          ดรีมเวิลด์  ...       0.0
# 58579                      รามคลินิกแพทย์  ...       0.0
# 139618    Klong Lat Mayom floating market  ...       0.0
# 204196                     โภชนากร หนองมน  ...      11.0
# 167551  ทรีท็อปแอดเวนเจอร์พาร์ค กาญจนบุรี  ...       4.0
#
# [5 rows x 3 columns]

# %%
london_index_list = no_misssing['avg_price']>1000  #มีร้านที่ราคามากกว่า 1000 มั้ย
no_misssing[london_index_list]
# Out:
#                                          name  ... avg_price
# 247                        Masterpiece clinic  ...    1500.0
# 3022             J'AIME by Jean-Michel Lorain  ...    1500.0
# 4798                              Xin Tian Di  ...    1500.0
# 5804          P10 Clinic ( Surgery Cosmetic )  ...    1500.0
# 7186                         THYME Eatery&Bar  ...    1500.0
# ...                                       ...  ...       ...
# 62474                                   Acqua  ...    1500.0
# 160729        Haven Love Cake By Love Andaman  ...    1500.0
# 221495  Panache (Angsana Villa Reaort Phuket)  ...    1500.0
# 57063       Jahn restaurant @Conrad Koh samui  ...    1500.0
# 203721           WOO BAR  W Retreat Koh Samui  ...    1500.0
#
# [185 rows x 3 columns]

# %% [markdown]
# #Smooth data (binning)

# %% [markdown]
# ###HW10 ทำ Binning smooth by mean ค่า 'avg_price' ในตาราง no_missing (bins = 50) ไปหาการเรียงค่าในตารางเอง แบ่ง iloc หา mean แล้วไปปรับค่า

# %% [markdown]
# #### 1 sort data by avg_price

# %%
sorted_no_missing = no_missing.sort_values('avg_price')
sorted_no_missing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-241-d57dc2abcbea> in <module>()
# ----> 1 sorted_no_missing = no_missing.sort_values('avg_price')
#       2 sorted_no_missing
#
# NameError: name 'no_missing' is not defined

# %% [markdown]
# #### 2 binning

# %%
import math
each_bin = no_missing.shape[0]/50
print(math.ceil(each_bin))

# %%
for i in range(50):
    no_missing.iloc[i*math.ceil(each_bin) : i*math.ceil(each_bin)+math.ceil(each_bin),:] #แบ่งbin
    this_mean = no_missing.iloc[i*math.ceil(each_bin) : i*math.ceil(each_bin)+math.ceil(each_bin),:]['avg_price'].mean() #หา  mean ของแต่ละ bin
    no_missing.iloc[i*math.ceil(each_bin) : i*math.ceil(each_bin)+math.ceil(each_bin),:] ['avg_price']=this_mean #เติมค่า mean ลงไปในแต่ละ bin
no_missing

# %%
no_missing.iloc[246845:246850,:] #เช็ค error

# %%
no_missing.iloc[246845:246850,:].mean()

# %% [markdown]
# ## Remove Outlier (boxplot)

# %% [markdown]
# # สร้าง Boxplot ของค่า Average price จากตาราง no_missing

# %%
from matplotlib import pyplot as plt
ret = plt.boxplot(no_missing['avg_price'], vert=False)

# %%
ret['boxes'][0].get_xdata()

# %%
print(ret['whiskers'][0].get_xdata())
print(ret['whiskers'][1].get_xdata())
#เอา 138 กับ 549 ออกมา

# %%
no_outlier_no_missing = no_missing[(no_missing['avg_price']>=ret['whiskers'][0].get_xdata()[1])]
no_outlier_no_missing = no_outlier_no_missing[(no_outlier_no_missing['avg_price']<=ret['whiskers'][1].get_xdata()[1])]

# %%
no_outlier_no_missing

# %%
len(no_missing)-len(no_outlier_no_missing)

# %% [markdown]
# # Deduplication(Sampling vs PCA)

# %% [markdown]
# Drop Deplicate Data

# %%
w_restaurant1.shape

# %%
w_restaurant1.drop_duplicates().shape

# %%
w_restaurant1.drop_duplicates(subset=['name']).shape

# %% [markdown]
# # Ex 11 Sample 1 restaurant from each city using drop_duplicates

# %%
w_restaurant1.drop_duplicates(subset=['city_name']) # ปริ้นออกมาเป็นตาราง

# %% [markdown]
# Sampling
# ใช้เพื่อเพิ่มข้อมูล

# %% [markdown]
# Boostraps Sampling

# %%
w_restaurant1.sample(n=10,replace=True)

# %% [markdown]
# # Principal Component Analysis (PCA)

# %%
from sklearn import datasets
from matplotlib import pyplot as plt

# %%
iris_data = datasets.load_iris()

# %%
iris_data

# %%
iris_data['target']

# %%
plt.scatter(iris_data['data'][:50,0],iris_data['data'][:50,1],s=100,c='c',alpha=0.5)
plt.scatter(iris_data['data'][:50,0],iris_data['data'][50:100,1],s=100,c='r',alpha=0.5)
plt.scatter(iris_data['data'][:50,0],iris_data['data'][100:150,1],s=100,c='y',alpha=0.5)

# %% [markdown]
# # Hw 12 Plot scatter 2d iris data โดย ทดลองทุก combination เช่น dimention 1 x imention 2, dimention 1 x imention 3 ... แล้วดูว่า Combination ไหนดีที่สุด

# %%
plt.scatter(iris_data['data'][:50,0],iris_data['data'][:50,2],s=100,c='c',alpha=0.5)
plt.scatter(iris_data['data'][:50,0],iris_data['data'][50:100,2],s=100,c='r',alpha=0.5)
plt.scatter(iris_data['data'][:50,0],iris_data['data'][100:150,2],s=100,c='y',alpha=0.5)

# %%
plt.scatter(iris_data['data'][:50,0],iris_data['data'][:50,3],s=100,c='c',alpha=0.5)
plt.scatter(iris_data['data'][:50,0],iris_data['data'][50:100,3],s=100,c='r',alpha=0.5)
plt.scatter(iris_data['data'][:50,0],iris_data['data'][100:150,3],s=100,c='y',alpha=0.5)

# %%
plt.scatter(iris_data['data'][:50,1],iris_data['data'][:50,2],s=100,c='c',alpha=0.5)
plt.scatter(iris_data['data'][:50,1],iris_data['data'][50:100,2],s=100,c='r',alpha=0.5)
plt.scatter(iris_data['data'][:50,1],iris_data['data'][100:150,2],s=100,c='y',alpha=0.5)

# %%
plt.scatter(iris_data['data'][:50,1],iris_data['data'][:50,3],s=100,c='c',alpha=0.5)
plt.scatter(iris_data['data'][:50,1],iris_data['data'][50:100,3],s=100,c='r',alpha=0.5)
plt.scatter(iris_data['data'][:50,1],iris_data['data'][100:150,3],s=100,c='y',alpha=0.5)

# %%
plt.scatter(iris_data['data'][:50,2],iris_data['data'][:50,3],s=100,c='c',alpha=0.5)
plt.scatter(iris_data['data'][:50,2],iris_data['data'][50:100,3],s=100,c='r',alpha=0.5)
plt.scatter(iris_data['data'][:50,2],iris_data['data'][100:150,3],s=100,c='y',alpha=0.5)

# %% [markdown]
# ## Data Integration (combine 2 tables vs copy some columns from another table)

# %% [markdown]
# รวมตาราง 2 ตารางทางขวามือ หาคอลัมนืเชื่อม เหมือนกัน ไว้เสิร์ช  อันไหนเป็นตารางหลักอันไหนตารางรอง How บอกตางหลักอยู่ด้านซ้ายนะ
# 1 merge
# 2 map สร้างคอลัมน์ copy จากตารางอื่น   เพิ่ม คล โดยดูจาก คล Business ไป map กับ BN ID

# %% [markdown]
# #merge two table

# %% [markdown]
# #Group by-Agregation

# %% [markdown]
# ช่วยให้เข้าใจตัวเดต้ามากขึ้น

# %%
search_click1.groupby('business_id').count()
# Out:
#              click_timestamp  search_id  display_position  time_diff_nanos  ads
# business_id
# 2.0                        4          4                 4                4    4
# 5.0                        2          2                 2                2    2
# 6.0                        6          6                 6                6    6
# 7.0                        3          3                 3                3    3
# 14.0                       5          5                 5                5    5
# ...                      ...        ...               ...              ...  ...
# 340060.0                   4          4                 4                4    4
# 340063.0                   1          1                 1                1    1
# 340067.0                   2          2                 2                2    2
# 340068.0                   6          6                 6                6    6
# 340070.0                   9          9                 9                9    9
#
# ...

# %%
search_click1.groupby('business_id').count().sort_values('click_timestamp')
# Out:
#              click_timestamp  search_id  ...  time_diff_nanos   ads
# business_id                              ...
# 122473.0                   1          1  ...                1     1
# 136485.0                   1          1  ...                1     1
# 275120.0                   1          1  ...                1     1
# 136492.0                   1          1  ...                1     1
# 136498.0                   1          1  ...                1     1
# ...                      ...        ...  ...              ...   ...
# 150227.0                1377       1377  ...             1377  1377
# 273486.0                1417       1417  ...             1417  1417
# 112509.0                2130       2130  ...             2130  2130
# 142707.0                2811       2811  ...             2811  2811
# 182530.0                3833       3833  ...             3833  3833
#
# [141536 rows x 5 columns]

# %%
Quiz 1 หาว่าร้านชื่ออะไรที่คนกดเข้าไปดูเยอะสุด

# %%
w_restaurant1[w_restaurant1['id']==182530.0]
# Out:
#             id      name  domain_id  ...  hotel_restaurant pet_friendly delivery
# 124030  182530  หนานหยวน          1  ...               NaN          NaN      NaN
#
# [1 rows x 32 columns]

# %%
w_restaurant1.groupby('city_name').mean()
# Out:
#                                       id  domain_id  ...  pet_friendly  delivery
# city_name                                            ...
# Abu Dhabi                  180200.000000   1.000000  ...           NaN       NaN
# Aichi-ken                  181557.633803   1.000000  ...           NaN       NaN
# Akershus                   196643.666667   1.000000  ...           NaN       NaN
# Akita-ken                   12908.000000   1.000000  ...           NaN       NaN
# Al Farwaniyah Governorate  166274.000000   1.000000  ...           NaN       NaN
# ...                                  ...        ...  ...           ...       ...
# Ōita-ken                   187412.791045   1.000000  ...           NaN       NaN
# Ōsaka-fu                   182106.134483   1.000000  ...           NaN       NaN
# محافظة المحرق               92784.000000   1.000000  ...           NaN       NaN
# สงขลา                      180144.823398   1.070950  ...       0.10084  0.616822
# ...

# %%
Ex 2 เมืองไหนได้ 'weighted_average_rating' เยอะสุด

# %%
w_restaurant1[w_restaurant1['weighted_average_rating']== 5]
# Out:
#             id               name  ...  pet_friendly  delivery
# 0            2   นครินทร์ทันตกรรม  ...           NaN       NaN
# 5           14        บ้านมุมสบาย  ...           0.0       0.0
# 12          28            Milkcow  ...           NaN       NaN
# 22          42  ข้าวขาหมู ป้าเพ็ญ  ...           NaN       NaN
# 81         149        WISH CLINIC  ...           NaN       NaN
# ...        ...                ...  ...           ...       ...
# 246788  339934              Silla  ...           NaN       NaN
# 246797  339943       Café in Mind  ...           0.0       0.0
# 246798  339944     เค.บี.การเกษตร  ...           NaN       NaN
# 246832  340042          โชคดีกาแฟ  ...           NaN       NaN
# 246845  340079           Mom Made  ...           NaN       NaN
#
# [15896 rows x 32 columns]

# %%
w_restaurant1.groupby('city_name').mean().sort_values('weighted_average_rating')
# Out:
#                            id  domain_id  ...  pet_friendly  delivery
# city_name                                 ...
# South Carolina        52860.5        1.0  ...           NaN       1.0
# Bahia                178713.0        1.0  ...           NaN       1.0
# Oklahoma             136441.0        1.0  ...           NaN       NaN
# Region Zealand       115070.0        1.0  ...           NaN       NaN
# Région de Kidal      240208.5        2.0  ...           NaN       NaN
# ...                       ...        ...  ...           ...       ...
# Oaxaca               278395.0        1.0  ...           NaN       NaN
# Wisconsin            107551.0        1.0  ...           NaN       NaN
# Murmanskaya oblast'   30394.0        1.0  ...           NaN       NaN
# Fribourg              73168.0        1.0  ...           NaN       NaN
# Khartoum             303589.0        1.0  ...           NaN       NaN
#
# [479 rows x 27 columns]

# %%
HW13 เมืองที่ได้ 5 ดาว แบบมีคนรีวิวเยอะสุด

# %%
w_restaurant1.groupby('city_name').mean().sort_values('weighted_average_rating').sort_values('number_of_reviews')
# Out:
#                                         id  domain_id  ...  pet_friendly  delivery
# city_name                                              ...
# South Carolina                52860.500000   1.000000  ...           NaN  1.000000
# Andalucía                    196640.000000   1.000000  ...           NaN       NaN
# West Sussex                  140710.000000   1.000000  ...           NaN       NaN
# Gombe                         99377.000000   1.000000  ...           NaN       NaN
# District of Columbia         173765.500000   1.000000  ...           NaN       NaN
# ...                                    ...        ...  ...           ...       ...
# Chon Buri                    179136.287061   1.168637  ...      0.096855  0.608209
# Maldives                     242953.000000   1.000000  ...           NaN       NaN
# Bangkok Metropolitan Region  179658.982155   1.117261  ...      0.162970  0.915868
# Chiang Mai                   179078.979643   1.168028  ...      0.067387  0.164958
# ...

# %%
w_restaurant1.groupby('city_name').mean().sort_values('weighted_average_rating')[w_restaurant1.groupby('city_name').mean().sort_values('weighted_average_rating')['number_of_reviews']==5]
# Out:
#                  id  domain_id  ...  pet_friendly  delivery
# city_name                       ...
# Maldives   242953.0        1.0  ...           NaN       NaN
#
# [1 rows x 27 columns]

# %%
w_restaurant1[w_restaurant1['weighted_average_rating']== 5].sort_values('number_of_reviews')
# Out:
#             id                                   name  ...  pet_friendly  delivery
# 174541  247933     6424 คิดถึงจังหวะ (Melody of 90's)  ...           NaN       NaN
# 216052  299430                Captain's Table Terrace  ...           NaN       NaN
# 60268    99742              Dr.Danai aesthetic clinic  ...           NaN       NaN
# 216032  299406                                  สีสวย  ...           NaN       NaN
# 83766   130106            Chinatown Riverview Seafood  ...           NaN       NaN
# ...        ...                                    ...  ...           ...       ...
# 111769  167077           So Relax Massage & Aesthetic  ...           NaN       NaN
# 145379  210687  ศาลาแดง ซ.1 ทันตกรรม (SDC1st Dentist)  ...           NaN       NaN
# 181597  256868                        V square Clinic  ...           NaN       NaN
# 165573  236581                        V Square Clinic  ...           NaN       NaN
# ...

# %%
w_restaurant1.groupby('city_name').mean().sort_values('weighted_average_rating')
# Out:
#                            id  domain_id  ...  pet_friendly  delivery
# city_name                                 ...
# South Carolina        52860.5        1.0  ...           NaN       1.0
# Bahia                178713.0        1.0  ...           NaN       1.0
# Oklahoma             136441.0        1.0  ...           NaN       NaN
# Region Zealand       115070.0        1.0  ...           NaN       NaN
# Région de Kidal      240208.5        2.0  ...           NaN       NaN
# ...                       ...        ...  ...           ...       ...
# Oaxaca               278395.0        1.0  ...           NaN       NaN
# Wisconsin            107551.0        1.0  ...           NaN       NaN
# Murmanskaya oblast'   30394.0        1.0  ...           NaN       NaN
# Fribourg              73168.0        1.0  ...           NaN       NaN
# Khartoum             303589.0        1.0  ...           NaN       NaN
#
# [479 rows x 27 columns]

# %%
T = w_restaurant1.groupby('city_name').mean().sort_values('weighted_average_rating')
T[T['weighted_average_rating']>4.3].sort_values('number_of_reviews')
# Out:
#                                     id  domain_id  ...  pet_friendly  delivery
# city_name                                          ...
# Murmanskaya oblast'       30394.000000        1.0  ...           NaN       NaN
# Buckinghamshire           28701.000000        1.0  ...           NaN       NaN
# Western Cape              82327.000000        1.0  ...           NaN       NaN
# Wisconsin                107551.000000        1.0  ...           NaN       NaN
# Oaxaca                   278395.000000        1.0  ...           NaN       NaN
# Guangxi Zhuangzuzizhiqu  112065.333333        1.0  ...           NaN       NaN
# Vorarlberg               224505.000000        1.0  ...           NaN       NaN
# Vladimirskaya oblast'    311200.000000        1.0  ...           NaN       NaN
# Primorskiy kray          157938.000000        1.0  ...           NaN       NaN
# Appenzell Ausserrhoden   167027.000000        1.0  ...           NaN       NaN
# ...

# %%
T.sort_values
